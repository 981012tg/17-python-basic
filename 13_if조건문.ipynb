# %%
# if의 조건문 사용하기

x=10

if x==10:
    print("10입니다")
# Out:
# 10입니다

# %%
x=10

if x==10:
   print("10입니다")   
   print("10입니다")   
   print("10입니다")   
   print("10입니다")
# Out:
# 10입니다
# 10입니다
# 10입니다
# 10입니다

# %%
#  if 조건문에서 코드를 생략하기
x = 10
if x==10:
    pass

# %%
# if 조건문과 들여쓰기
x=10
if x==10:
    print("x에 들어가는 숫자는")
    print("10입니다")
# Out:
# x에 들어가는 숫자는
# 10입니다

# %%
if x==10:
    print("x에 들어가는 숫자는")
print("10입니다")
# Out:
# x에 들어가는 숫자는
# 10입니다

# %%
x=5
if x==10:
    print("x에 들어가는 숫자는")
                                 # convention(if 끝나면 한줄 띄우기)
print("10입니다")
# Out:
# 10입니다

# %%
# 중첩 if 조건문
x=15

if x > 10:
    print("10 이상입니다")

    if x == 15:
        print("15 입니다")

    if x == 20:
        print("20 입니다")
# Out:
# 10 이상입니다
# 15 입니다

# %%
#사용자가 입력한 값에 if 조건문 사용하기
x=int(input())

if x==10:
    print("10입니다.")

if x==20:
    print("20입니다")

# %%
#연습문제(p.164)

x=5

if x != 10:
    print('ok')
# Out:
# ok
