# %%
# import 모듈 가져오기

# import 모듈
# import 모듈1, 모듈2

# 모듈.변수
# 모듈.함수()
# 모듈.클래스()

import math
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
## import as로 모듈 이름 지정하기

#import 모듈 as 이름

import math as m
m.sqrt(4)
# Out:
# 2.0
