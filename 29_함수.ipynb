# %%
# 함수 만들기
# def 함수이름():
#     코드

def hello():
    print("Hello, world!")

# %%
hello()
# Out:
# Hello, world!

# %%
hello2()

def hello2():
    print("hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hello2()
#       2
#       3 def hello2():
#       4     print("hello world")
#
# NameError: name 'hello2' is not defined

# %%
# 덧셈함수 만들기

def add(a, b):
    print(a + b)

# %%
add (10,20)
# Out:
# 30

# %%
#독스트링(p.375~376)

# %%
# 함수의 결과를 반환하기
# def add(a, b):
#     print(a + b)
#     # return None
    
def add(a, b):
    return a + b

# %%
x = add(10, 20)
x
# Out:
# 30

# %%
def add2(a, b):
    print(a + b)
    return

# %%
y = add2(10, 20)
print(y)
# Out:
# 30
# None

# %%
# 함수에서 값을 여러 개 반환하기
def add_sub(a, b):
    return a + b, a - b
	#return a+b
    #return a-b  이런식으로 연속으로 return이 연속해서 나올수 없음 (if 반복문 등에서 안과 바깥 각각 연속으로 나오는건 가능)

# %%
c = add_sub(10,20)

# %%
c
# Out:
# (30, -10)

# %%
x, y = add_sub(10,20)

# %%
x
# Out:
# 30

# %%
y
# Out:
# -10

# %%
# 함수의 호출 과정 알아보기
def mul(a,b):
    c=a*b
    return c




def add(a,b):    #위에서 a,b를 썼는데 또 써도 되나?? --> 됨. 이 매개 변수는 한 def 안에서만 유효함
    c=a+b
    print(c)
    d =mul(a,b)
    print(d)

x=10
y=20
add(x,y)
# Out:
# 30
# 200
