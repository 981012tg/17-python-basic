# %%
# 나눗셈 후 소수점 이하를 버리는 연산자
5//2
# Out:
# int

# %%
# 나눗셈 후 나머지를 구하는 % 연산자
5%2
# Out:
# 1

# %%
#거듭제곱을 구하는 연산자 ** 연산자
2**10
# Out:
# 1024

# %%
#값을 정수로 만들기
a=3.3
print(int(a)) # a의 실수부분만 나옴

b='10'
print(type(b))  
b=int(b)
print(type(b)) #type 이 str(문자열)에서 int(정수)로 바뀜
# Out:
# 3
# <class 'str'>
# <class 'int'>

# %%
# 실수 계산 하기
3.5+2.1
# Out:
# 5.6

# %%
#실수와 정수를 함께 계산하기
4.2+5
# Out:
# 9.2

# %%
# float() 함수를 이용하여 정수를 실수로 변환
print(float(5))
print(float(1+2))
print(float('5.3'))
a=float('5.3')
print(type(a)) #type 이 str(문자열)에서 float(실수)로 바뀜
# Out:
# 5.0
# 3.0
# 5.3
# <class 'float'>

# %%
# 괄호 사용하기 
print(35+1*2)
print((35+1)*2) #괄호를 사용하면 괄호 안의 연산이 먼저 수행됨
# Out:
# 37
# 72

# %%
#퀴즈(p.61)
#1
print(10/4)
#2
print(float(10//3))
#3
print(7+(10-5)*2)
# Out:
# 2.5
# 3.0
# 17

# %%
#연습문제(p.62)
#소음이 가장 심한층은 0.2467*(도로와의거리(m))+4.159
#이때, 소음이 가장 심한 층수가 출력되게 만드시오
#도로와의 거리는 12m, 층수는 정수로 출력되게, 소수점 이하자리는 버림

print(int(0.2467*12+4.159))
# Out:
# 7
