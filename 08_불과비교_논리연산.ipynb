# %%
#불과 비교 연산자 사용하기
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
#비교연산자
3>1
# Out:
# True

# %%
print(10==10)  #TMI:다른 언어에서, ===라고 하면  type까지 같음을 의미,  파이썬엔 없다.
print(10!=5)
# Out:
# True
# True

# %%
print("Python"=="Python")
print("Python"=="python")
print("Python"!="python")
# Out:
# True
# False
# True

# %%
#부등호 사용하기
print(10>20)
print(10<20)
print(10>=20)
print(10<=20)
# Out:
# False
# True
# False
# True

# %%
#객체가 같은지 다른지 비교하기

print(1==1.0)
print(1 is 1.0) #권장하지 않는 방식
print(1 is not 1.0) #권장하지 않는 방식
# Out:
# True
# False
# True
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\KDS-30\AppData\Local\Temp\ipykernel_10192\1000594546.py:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0) #권장하지 않는 방식
# C:\Users\KDS-30\AppData\Local\Temp\ipykernel_10192\1000594546.py:5: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print(1 is not 1.0) #권장하지 않는 방식

# %%
#논리연산자 사용하기
print(True and True)
print(True and False)
print(False and True)
print(False and False)
#하나라도 False가 있으면 False
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
#하나라도 True가 있으면 True
# Out:
# True
# True
# True
# False

# %%
print(not True)
print(not False)
# Out:
# False
# True

# %%
print(not True and False or not False)

print((not True) and False or (not False))
# Out:
# True
# True

# %%
#논리연산자와 비교연산자를 함께 사용하기
10==10 and 10!=5
# Out:
# True

# %%
print(10>5 or 10<3)
print(not 10>5)
print(1 is 1.0)
# Out:
# True
# False
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDS-30\AppData\Local\Temp\ipykernel_10192\164178951.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
#퀴즈(p.93)
#1
#print(x==5)
#2
print(6==2*3)
print(4!=2+2)
print(2*3 is 3+3)
print(8 is 4*2.0)
print(5 is 6-1.1)
#3
a=10
b=20

print(a==10 or b==10)
print(a>=10 and b<30)
print(not a==10)
print(b != 20 or a !=10)
print(not b != 20 and a >5)

#4 not
k=92
e=47
m=86
s=81

#연습문제(p.94)
print(k>=50 and e>=50 and m>=50 and s>=81 )
# Out:
# True
# False
# True
# False
# False
# True
# True
# False
# False
# True
# False
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDS-30\AppData\Local\Temp\ipykernel_10192\3023096380.py:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(8 is 4*2.0)
# C:\Users\KDS-30\AppData\Local\Temp\ipykernel_10192\3023096380.py:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(5 is 6-1.1)
