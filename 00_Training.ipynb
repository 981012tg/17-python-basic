# %%
korean = 92
english = 47
mathematics = 86
science = 81

print(korean >= 50 and english >=50 and mathematics >= 50 and science >= 50)
# Out:
# False

# %%
korean, english, math, science = map(int, input().split())

print(korean >= 90 and english > 80 and math > 85 and science >= 80)
# Out:
# True

# %%
s = """'Python' is a "programming language"
that lets you work quickly
and
integrate systems more effectively."""

print(s)
# Out:
# 'Python' is a "programming language"
# that lets you work quickly
# and
# integrate systems more effectively.

# %%
a = list(range(5,-10,-2))

list(a)
# Out:
# [5, 3, 1, -1, -3, -5, -7, -9]

# %%
x = int(input())

tuple(range(-10,10,x))
# Out:
# (-10, -7, -4, -1, 2, 5, 8)

# %%
year = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
population=[10249679, 10195318, 10143645, 101023233, 10022181, 9930616, 9857426, 9838892]

print(year[-3:])
print(population[-3:])
# Out:
# [2016, 2017, 2018]
# [9930616, 9857426, 9838892]

# %%
n = -32, 75, 97, -10, 9, 32, 4, -15, 0, 76, 14, 2

print(n[1::2])
# Out:
# (75, -10, 32, -15, 76, 2)

# %%
x = input().split()

del x[-5:]

tuple(x)
# Out:
# ('oven', 'bat', 'pony', 'total', 'leak', 'wreck', 'curl')

# %%
str1 = input()
str2 = input()

print(str1[1::2] + str2[0::2])
# Out:
# yhnpto

# %%
ability = input().split()
number = input().split()

character = dict(zip(ability, number))

print(character)
# Out:
# {'health': '575.6', 'health_regen': '1.7', 'mana': '338.8', 'nama_regen': '1.63'}

# %%
x = 5

if x !=10:
    print('ok')
# Out:
# ok

# %%
money = int(input())
coupon = input()

if coupon == 'Cash3000':
    print(money-3000)

if coupon == 'Cash5000':
    print(money-5000)
# Out:
# 24000

# %%
written_test = 75
coding_test = True

if written_test >= 80 and coding_test == True:
    print('합격')
else:
    print('불합격')
# Out:
# 불합격

# %%
korean, english, math, science = map(int, input().split())

if 0 <= korean <= 100 and 0 <= english <=100 and 0 <= math <= 100 and 0 <= science <= 100:
    avg = (korean + english + math + science)/4
    if avg >= 80:
        print("합격")
    else:
        print("불합격")
else:
    print("잘못된 점수")
# Out:
# 잘못된 점수

# %%
age = int(input())
balance = 9000

if age >=7:
    if 7 <= age <= 12 :
        balance -= 650
    elif 13 <= age <= 18:
        balance -= 1050
    else:
        balance -= 1250
    print(balance)

# %%
dan = int(input())

for num in range(1,10):
    print(f"{dan} * {num} = {dan*num}")
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18

# %%
i = 2
j = 5

while i <=32 or j >=1:
    print(i,j)
    i *= 2
    j -= 1
# Out:
# 2 5
# 4 4
# 8 3
# 16 2
# 32 1

# %%
balance = int(input())

while balance - 1350 >= 0:
    print(balance-1350)
    balance -= 1350
# Out:
# 12150
# 10800
# 9450
# 8100
# 6750
# 5400
# 4050
# 2700
# 1350
# 0

# %%
i = 0

while True:
    if i % 10 != 3:
        i += 1
        continue

    if i >73:
        break

    print(i, end=' ')
    i +=1
# Out:
# 3 13 23 33 43 53 63 73

# %%
start, stop = map(int, input().split())

i = start

while True:
    if i % 10 == 3:
        i += 1
        continue

    if i > stop:
        break

    print(i, end=' ')
    i += 1
# Out:
# 21 22 24 25 26 27 28 29 30 31 32

# %%
for i in range(5):
    for j in range(5):
        print("*", end='')
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for i in range(5):
    for j in range(5):
        if j <= i:
            print("*", end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(5):
    for j in range(5):
        if j < i:
            print(" ", end='')
        if j == i:
            print("*", end='')

    print()
# Out:
# *
#  *
#   *
#    *
#     *

# %%
for i in range(5):
    for j in range(5):
        if j == i:
            print("*", end='')
        else:
            print(" ", end='')
    print()
# Out:
# *
#  *
#   *
#    *
#     *

# %%
for i in range(5):
    for j in range(5):
        if j >= i :
            print('*', end='')
        else:
            print(' ', end='')
    print()
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
height = int(input())

for i in range(height):
    for j in range(height-i-1):
        print(" ", end='')
    for k in range(2*i+1):
        print("*", end='')
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
for i in range(1,51):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz

# %%
start, end = map(int, input().split())

for i in range(start, end + 1):
    if i % 5 == 0 and i % 7 == 0:
        print("FizzBuzz")
    elif i % 5 == 0:
        print("Fizz")
    elif i % 7 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# FizzBuzz
# 36
# 37
# 38
# 39
# Fizz

# %%
a=['alpha', 'bravo', 'charlie', 'delta', 'echo', 'foxtrot', 'golf', 'hotel', 'india']
b=[i for i in a if len(i) == 5]

print(b)
# Out:
# ['alpha', 'bravo', 'delta', 'hotel', 'india']

# %%
start, end = map(int, input().split())

a=[2**i for i in range(start, end+1)]

del a[1]
del a[-2]

print(a)
# Out:
# [1024, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 1048576]
